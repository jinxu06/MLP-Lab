# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
import cPickle as pickle
# %matplotlib inline
plt.style.use('ggplot')
# %load_ext autoreload
# %autoreload 2

logger = logging.getLogger()
logger.setLevel("INFO") 
logger.handlers = [logging.StreamHandler()] 
seed = 20161121
rng = np.random.RandomState(seed)

# %%
from mlp.models import MultipleLayerModel
from mlp.layers import AffineLayer, ConvolutionalLayer, MaxPoolingLayer, ReshapeLayer
from mlp.layers import SigmoidLayer, TanhLayer, ReluLayer, DropoutLayer
from mlp.data_providers import MNISTDataProvider, MNISTCNNAutoencoderDataProvider, MNISTCNNDataProvider
from mlp.data_providers import MNISTCNNDenoisingAutoencoderDataProvider
from mlp.errors import CNNSumOfSquaredDiffsError, CrossEntropySoftmaxError
from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule
from mlp.schedulers import ConstantLearningRateScheduler, ExponentialLearningRateScheduler
from mlp.penalties import L1Penalty, L2Penalty
from mlp.initialisers import GlorotUniformInit, ConstantInit, UniformInit
from mlp.optimisers import Optimiser
from mlp.settings import Setting
from mlp.experiments import Experiment

# %%
kernels_init = UniformInit(-0.01,0.01,rng=rng)
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

learning_rule = GradientDescentLearningRule(learning_rate=0.1)
error = CrossEntropySoftmaxError()
# ae_error = CNNSumOfSquaredDiffsError()

# %%
train_set = MNISTDataProvider(which_set='train', batch_size=10, max_num_batches=-1, rng=rng)
valid_set = MNISTDataProvider(which_set='valid', batch_size=10, max_num_batches=-1, rng=rng)

# %%
layers = [
    AffineLayer(input_dim=784, output_dim=100, weights_initialiser=weights_init, weights_penalty=L2Penalty(0.0001)),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=100, weights_initialiser=weights_init, weights_penalty=L2Penalty(0.0001)),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init, weights_penalty=L2Penalty(0.0001))
]

model = MultipleLayerModel(layers)

setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "3 layer normal nn"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=400, stats_interval=1, remark=remark)
experiment.do_experiment()
# Out:
# Epoch 0:
#   error(train)=2.35e+00, acc(train)=1.06e-01, error(valid)=2.34e+00, acc(valid)=1.11e-01, params_penalty=1.47e-02
# Epoch 1: 4.70s to complete
#   error(train)=2.07e-01, acc(train)=9.36e-01, error(valid)=2.09e-01, acc(valid)=9.38e-01, params_penalty=2.12e-02
# Epoch 2: 5.20s to complete
#   error(train)=1.36e-01, acc(train)=9.59e-01, error(valid)=1.46e-01, acc(valid)=9.57e-01, params_penalty=2.47e-02
# Epoch 3: 4.80s to complete
#   error(train)=1.09e-01, acc(train)=9.67e-01, error(valid)=1.33e-01, acc(valid)=9.61e-01, params_penalty=2.73e-02
# Epoch 4: 3.97s to complete
#   error(train)=9.64e-02, acc(train)=9.70e-01, error(valid)=1.29e-01, acc(valid)=9.62e-01, params_penalty=2.96e-02
# Epoch 5: 3.91s to complete
#   error(train)=7.39e-02, acc(train)=9.78e-01, error(valid)=1.18e-01, acc(valid)=9.68e-01, params_penalty=3.15e-02
# Epoch 6: 3.99s to complete
#   error(train)=6.03e-02, acc(train)=9.82e-01, error(valid)=1.03e-01, acc(valid)=9.70e-01, params_penalty=3.30e-02
# Epoch 7: 3.93s to complete
#   error(train)=5.47e-02, acc(train)=9.83e-01, error(valid)=9.68e-02, acc(valid)=9.71e-01, params_penalty=3.42e-02
# Epoch 8: 3.90s to complete
#   error(train)=5.44e-02, acc(train)=9.83e-01, error(valid)=1.03e-01, acc(valid)=9.70e-01, params_penalty=3.52e-02
# Epoch 9: 3.92s to complete
#   error(train)=4.96e-02, acc(train)=9.84e-01, error(valid)=1.05e-01, acc(valid)=9.70e-01, params_penalty=3.61e-02
# Epoch 10: 4.27s to complete
#   error(train)=4.80e-02, acc(train)=9.85e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=3.68e-02
# Epoch 11: 4.00s to complete
#   error(train)=3.66e-02, acc(train)=9.89e-01, error(valid)=9.21e-02, acc(valid)=9.75e-01, params_penalty=3.75e-02
# Epoch 12: 3.90s to complete
#   error(train)=5.28e-02, acc(train)=9.83e-01, error(valid)=1.14e-01, acc(valid)=9.69e-01, params_penalty=3.81e-02
# Epoch 13: 4.04s to complete
#   error(train)=3.41e-02, acc(train)=9.89e-01, error(valid)=9.93e-02, acc(valid)=9.73e-01, params_penalty=3.85e-02
# Epoch 14: 4.13s to complete
#   error(train)=2.92e-02, acc(train)=9.91e-01, error(valid)=9.53e-02, acc(valid)=9.75e-01, params_penalty=3.88e-02
# Epoch 15: 4.11s to complete
#   error(train)=2.85e-02, acc(train)=9.91e-01, error(valid)=9.05e-02, acc(valid)=9.75e-01, params_penalty=3.90e-02
# Epoch 16: 3.96s to complete
#   error(train)=2.38e-02, acc(train)=9.93e-01, error(valid)=8.92e-02, acc(valid)=9.76e-01, params_penalty=3.92e-02
# Epoch 17: 4.33s to complete
#   error(train)=2.49e-02, acc(train)=9.92e-01, error(valid)=8.95e-02, acc(valid)=9.74e-01, params_penalty=3.95e-02
# Epoch 18: 4.03s to complete
#   error(train)=2.21e-02, acc(train)=9.93e-01, error(valid)=8.84e-02, acc(valid)=9.76e-01, params_penalty=3.94e-02
# Epoch 19: 3.96s to complete
#   error(train)=2.16e-02, acc(train)=9.93e-01, error(valid)=9.37e-02, acc(valid)=9.74e-01, params_penalty=3.93e-02
# Epoch 20: 4.04s to complete
#   error(train)=3.59e-02, acc(train)=9.88e-01, error(valid)=1.15e-01, acc(valid)=9.68e-01, params_penalty=3.94e-02
# Epoch 21: 3.93s to complete
#   error(train)=1.73e-02, acc(train)=9.95e-01, error(valid)=8.27e-02, acc(valid)=9.77e-01, params_penalty=3.92e-02
# Epoch 22: 4.02s to complete
#   error(train)=1.75e-02, acc(train)=9.95e-01, error(valid)=8.84e-02, acc(valid)=9.76e-01, params_penalty=3.92e-02
# Epoch 23: 4.03s to complete
#   error(train)=1.55e-02, acc(train)=9.96e-01, error(valid)=8.20e-02, acc(valid)=9.77e-01, params_penalty=3.90e-02
# Epoch 24: 4.24s to complete
#   error(train)=1.25e-02, acc(train)=9.97e-01, error(valid)=8.41e-02, acc(valid)=9.76e-01, params_penalty=3.86e-02
# Epoch 25: 3.97s to complete
#   error(train)=1.67e-02, acc(train)=9.95e-01, error(valid)=8.74e-02, acc(valid)=9.78e-01, params_penalty=3.85e-02
# Epoch 26: 3.94s to complete
#   error(train)=1.29e-02, acc(train)=9.96e-01, error(valid)=8.53e-02, acc(valid)=9.75e-01, params_penalty=3.83e-02
# Epoch 27: 3.99s to complete
#   error(train)=1.43e-02, acc(train)=9.96e-01, error(valid)=8.89e-02, acc(valid)=9.77e-01, params_penalty=3.81e-02
# Epoch 28: 3.96s to complete
#   error(train)=1.65e-02, acc(train)=9.95e-01, error(valid)=9.27e-02, acc(valid)=9.74e-01, params_penalty=3.77e-02
# Epoch 29: 4.31s to complete
#   error(train)=1.47e-02, acc(train)=9.95e-01, error(valid)=9.44e-02, acc(valid)=9.74e-01, params_penalty=3.74e-02
# Epoch 30: 3.95s to complete
#   error(train)=9.50e-03, acc(train)=9.98e-01, error(valid)=8.33e-02, acc(valid)=9.78e-01, params_penalty=3.71e-02
# Epoch 31: 4.03s to complete
#   error(train)=1.34e-02, acc(train)=9.96e-01, error(valid)=8.90e-02, acc(valid)=9.76e-01, params_penalty=3.69e-02
# Epoch 32: 3.95s to complete
#   error(train)=1.11e-02, acc(train)=9.97e-01, error(valid)=8.83e-02, acc(valid)=9.77e-01, params_penalty=3.68e-02
# Epoch 33: 4.18s to complete
#   error(train)=1.35e-02, acc(train)=9.96e-01, error(valid)=9.65e-02, acc(valid)=9.76e-01, params_penalty=3.68e-02
# Epoch 34: 3.99s to complete
#   error(train)=1.38e-02, acc(train)=9.96e-01, error(valid)=8.82e-02, acc(valid)=9.76e-01, params_penalty=3.68e-02
# Epoch 35: 3.97s to complete
#   error(train)=1.10e-02, acc(train)=9.97e-01, error(valid)=8.47e-02, acc(valid)=9.77e-01, params_penalty=3.67e-02
# Epoch 36: 4.03s to complete
#   error(train)=1.23e-02, acc(train)=9.97e-01, error(valid)=9.46e-02, acc(valid)=9.76e-01, params_penalty=3.67e-02
# Epoch 37: 4.04s to complete
#   error(train)=1.04e-02, acc(train)=9.97e-01, error(valid)=9.08e-02, acc(valid)=9.76e-01, params_penalty=3.64e-02
# Epoch 38: 4.07s to complete
#   error(train)=1.27e-02, acc(train)=9.96e-01, error(valid)=9.15e-02, acc(valid)=9.76e-01, params_penalty=3.64e-02
# Epoch 39: 3.94s to complete
#   error(train)=1.32e-02, acc(train)=9.96e-01, error(valid)=9.12e-02, acc(valid)=9.76e-01, params_penalty=3.62e-02
# Epoch 40: 4.04s to complete
#   error(train)=2.22e-02, acc(train)=9.93e-01, error(valid)=1.06e-01, acc(valid)=9.71e-01, params_penalty=3.60e-02
# Epoch 41: 3.93s to complete
#   error(train)=8.18e-03, acc(train)=9.98e-01, error(valid)=8.99e-02, acc(valid)=9.76e-01, params_penalty=3.55e-02
# Epoch 42: 4.04s to complete
#   error(train)=9.63e-03, acc(train)=9.98e-01, error(valid)=8.58e-02, acc(valid)=9.78e-01, params_penalty=3.53e-02
# Epoch 43: 3.96s to complete
#   error(train)=1.79e-02, acc(train)=9.94e-01, error(valid)=1.02e-01, acc(valid)=9.74e-01, params_penalty=3.49e-02
# Epoch 44: 3.96s to complete
#   error(train)=2.42e-02, acc(train)=9.92e-01, error(valid)=1.13e-01, acc(valid)=9.69e-01, params_penalty=3.51e-02
# Epoch 45: 4.06s to complete
#   error(train)=1.46e-02, acc(train)=9.95e-01, error(valid)=9.77e-02, acc(valid)=9.73e-01, params_penalty=3.50e-02
# Epoch 46: 4.00s to complete
#   error(train)=9.79e-03, acc(train)=9.98e-01, error(valid)=9.22e-02, acc(valid)=9.75e-01, params_penalty=3.47e-02
# Epoch 47: 4.08s to complete
#   error(train)=1.13e-02, acc(train)=9.97e-01, error(valid)=9.36e-02, acc(valid)=9.75e-01, params_penalty=3.46e-02
# Epoch 48: 3.95s to complete
#   error(train)=1.39e-02, acc(train)=9.96e-01, error(valid)=9.33e-02, acc(valid)=9.75e-01, params_penalty=3.44e-02
# Epoch 49: 4.05s to complete
#   error(train)=1.46e-02, acc(train)=9.95e-01, error(valid)=9.42e-02, acc(valid)=9.77e-01, params_penalty=3.43e-02
# Epoch 50: 4.84s to complete
#   error(train)=6.90e-03, acc(train)=9.99e-01, error(valid)=8.10e-02, acc(valid)=9.79e-01, params_penalty=3.44e-02
# Epoch 51: 3.93s to complete
#   error(train)=9.70e-03, acc(train)=9.98e-01, error(valid)=9.03e-02, acc(valid)=9.76e-01, params_penalty=3.44e-02
# Epoch 52: 3.98s to complete
#   error(train)=1.02e-02, acc(train)=9.97e-01, error(valid)=8.27e-02, acc(valid)=9.79e-01, params_penalty=3.45e-02
# Epoch 53: 3.93s to complete
#   error(train)=1.34e-02, acc(train)=9.96e-01, error(valid)=9.27e-02, acc(valid)=9.76e-01, params_penalty=3.43e-02
# Epoch 54: 4.05s to complete
#   error(train)=9.82e-03, acc(train)=9.97e-01, error(valid)=9.05e-02, acc(valid)=9.76e-01, params_penalty=3.44e-02
# Epoch 55: 3.94s to complete
#   error(train)=1.79e-02, acc(train)=9.94e-01, error(valid)=9.14e-02, acc(valid)=9.76e-01, params_penalty=3.47e-02
# Epoch 56: 4.48s to complete
#   error(train)=9.82e-03, acc(train)=9.98e-01, error(valid)=8.10e-02, acc(valid)=9.79e-01, params_penalty=3.49e-02
# Epoch 57: 3.97s to complete
#   error(train)=8.58e-03, acc(train)=9.98e-01, error(valid)=8.51e-02, acc(valid)=9.77e-01, params_penalty=3.47e-02
# Epoch 58: 4.07s to complete
#   error(train)=9.39e-03, acc(train)=9.98e-01, error(valid)=8.36e-02, acc(valid)=9.78e-01, params_penalty=3.45e-02
# Epoch 59: 4.10s to complete
#   error(train)=7.51e-03, acc(train)=9.99e-01, error(valid)=8.11e-02, acc(valid)=9.77e-01, params_penalty=3.41e-02
# Epoch 60: 3.98s to complete
#   error(train)=5.50e-03, acc(train)=9.99e-01, error(valid)=7.81e-02, acc(valid)=9.79e-01, params_penalty=3.35e-02
# Epoch 61: 4.02s to complete
#   error(train)=8.26e-03, acc(train)=9.98e-01, error(valid)=8.78e-02, acc(valid)=9.77e-01, params_penalty=3.31e-02
# Epoch 62: 4.94s to complete
#   error(train)=6.97e-03, acc(train)=9.99e-01, error(valid)=7.62e-02, acc(valid)=9.80e-01, params_penalty=3.25e-02
# Epoch 63: 5.26s to complete
#   error(train)=1.07e-02, acc(train)=9.97e-01, error(valid)=8.66e-02, acc(valid)=9.78e-01, params_penalty=3.19e-02
# Epoch 64: 4.28s to complete
#   error(train)=1.01e-02, acc(train)=9.98e-01, error(valid)=8.59e-02, acc(valid)=9.78e-01, params_penalty=3.14e-02
# Epoch 65: 4.07s to complete
#   error(train)=1.81e-02, acc(train)=9.95e-01, error(valid)=9.18e-02, acc(valid)=9.75e-01, params_penalty=3.17e-02
# Epoch 66: 4.09s to complete
#   error(train)=9.83e-03, acc(train)=9.98e-01, error(valid)=8.44e-02, acc(valid)=9.78e-01, params_penalty=3.19e-02
# Epoch 67: 3.89s to complete
#   error(train)=1.32e-02, acc(train)=9.96e-01, error(valid)=8.36e-02, acc(valid)=9.78e-01, params_penalty=3.26e-02
# Epoch 68: 4.03s to complete
#   error(train)=1.56e-02, acc(train)=9.95e-01, error(valid)=8.63e-02, acc(valid)=9.77e-01, params_penalty=3.29e-02
# Epoch 69: 3.92s to complete
#   error(train)=1.30e-02, acc(train)=9.96e-01, error(valid)=8.48e-02, acc(valid)=9.77e-01, params_penalty=3.31e-02
# Epoch 70: 4.02s to complete
#   error(train)=1.28e-02, acc(train)=9.96e-01, error(valid)=9.02e-02, acc(valid)=9.77e-01, params_penalty=3.30e-02
# Epoch 71: 3.93s to complete
#   error(train)=1.50e-02, acc(train)=9.96e-01, error(valid)=8.55e-02, acc(valid)=9.77e-01, params_penalty=3.31e-02
# Epoch 72: 4.57s to complete
#   error(train)=1.27e-02, acc(train)=9.96e-01, error(valid)=8.46e-02, acc(valid)=9.77e-01, params_penalty=3.32e-02
# Epoch 73: 4.07s to complete
#   error(train)=1.77e-02, acc(train)=9.94e-01, error(valid)=9.63e-02, acc(valid)=9.75e-01, params_penalty=3.30e-02
# Epoch 74: 4.03s to complete
#   error(train)=5.90e-03, acc(train)=9.99e-01, error(valid)=7.84e-02, acc(valid)=9.79e-01, params_penalty=3.27e-02
# Epoch 75: 4.01s to complete
#   error(train)=8.41e-03, acc(train)=9.98e-01, error(valid)=8.53e-02, acc(valid)=9.78e-01, params_penalty=3.23e-02
# Epoch 76: 4.19s to complete
#   error(train)=5.46e-03, acc(train)=9.99e-01, error(valid)=7.69e-02, acc(valid)=9.80e-01, params_penalty=3.18e-02
# Epoch 77: 5.83s to complete
#   error(train)=1.07e-02, acc(train)=9.97e-01, error(valid)=8.15e-02, acc(valid)=9.78e-01, params_penalty=3.14e-02
# Epoch 78: 5.37s to complete
#   error(train)=4.51e-03, acc(train)=1.00e+00, error(valid)=7.18e-02, acc(valid)=9.81e-01, params_penalty=3.08e-02
# Epoch 79: 4.62s to complete
#   error(train)=5.74e-03, acc(train)=9.99e-01, error(valid)=7.78e-02, acc(valid)=9.79e-01, params_penalty=3.05e-02
# Epoch 80: 4.33s to complete
#   error(train)=4.50e-03, acc(train)=1.00e+00, error(valid)=7.67e-02, acc(valid)=9.79e-01, params_penalty=3.02e-02
# Epoch 81: 4.11s to complete
#   error(train)=8.96e-03, acc(train)=9.98e-01, error(valid)=8.45e-02, acc(valid)=9.79e-01, params_penalty=2.99e-02
# Epoch 82: 4.78s to complete
#   error(train)=1.86e-02, acc(train)=9.94e-01, error(valid)=9.36e-02, acc(valid)=9.75e-01, params_penalty=3.10e-02
# Epoch 83: 4.59s to complete
#   error(train)=1.72e-02, acc(train)=9.95e-01, error(valid)=9.78e-02, acc(valid)=9.75e-01, params_penalty=3.20e-02
# Epoch 84: 4.43s to complete
#   error(train)=8.55e-03, acc(train)=9.98e-01, error(valid)=7.87e-02, acc(valid)=9.79e-01, params_penalty=3.28e-02
# Epoch 85: 4.34s to complete
#   error(train)=2.71e-02, acc(train)=9.91e-01, error(valid)=9.85e-02, acc(valid)=9.73e-01, params_penalty=3.33e-02
# Epoch 86: 4.91s to complete
#   error(train)=1.01e-02, acc(train)=9.97e-01, error(valid)=8.47e-02, acc(valid)=9.77e-01, params_penalty=3.32e-02
# Epoch 87: 4.22s to complete
#   error(train)=1.34e-02, acc(train)=9.96e-01, error(valid)=8.92e-02, acc(valid)=9.77e-01, params_penalty=3.31e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-4a6732e664c9> in <module>()
#      15 settings = [setting]
#      16 experiment = Experiment(settings=settings, num_epoch=400, stats_interval=1, remark=remark)
# ---> 17 experiment.do_experiment()
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/experiments.py in do_experiment(self)
#      47             optimiser = SOptimiser(setting.model, setting.error, setting.learning_rule,
#      48                                   setting.train_set, setting.valid_set, self.data_monitors, setting.schedulers)
# ---> 49             stats, keys, run_time = optimiser.train(self.num_epoch, self.stats_interval)
#      50
#      51             with open(DIR+"/"+str(1)+"/activations.pkl", 'wb') as f:
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/optimisers.py in train(self, num_epochs, stats_interval)
#     148                 scheduler.update_learning_rule(self.learning_rule, epoch - 1)
#     149             start_time = time.time()
# --> 150             self.do_training_epoch()
#     151             epoch_time = time.time() - start_time
#     152             if epoch % stats_interval == 0:
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/optimisers.py in do_training_epoch(self)
#     182                 grads_wrt_outputs = self.error.grad(activations[-1], train_targets_batch)
#     183                 grads_wrt_params = self.model.grads_wrt_params(
# --> 184                     activations, grads_wrt_outputs)
#     185                 self.learning_rule.update_params(grads_wrt_params)
#     186
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/models.py in grads_wrt_params(self, activations, grads_wrt_outputs)
#     140                 # give gradients in consistent order with self.params
#     141                 grads_wrt_params += layer.grads_wrt_params(
# --> 142                     inputs, grads_wrt_outputs)[::-1]
#     143             # If not at first layer back-propagate gradients
#     144             if i != len(self.layers) - 1:
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/layers.pyc in grads_wrt_params(self, inputs, grads_wrt_outputs)
#     235
#     236         if self.weights_penalty is not None:
# --> 237             grads_wrt_weights += self.weights_penalty.grad(self.weights)
#     238
#     239         if self.biases_penalty is not None:
#
# KeyboardInterrupt:

# %%
import copy

model_1 = copy.deepcopy(model)
model_2 = copy.deepcopy(model)
model_3 = copy.deepcopy(model)

learning_rule_1 = MomentumLearningRule(learning_rate=0.02, mom_coeff=0.9)
learning_rule_2 = MomentumLearningRule(learning_rate=0.02, mom_coeff=0.9)
learning_rule_3 = MomentumLearningRule(learning_rate=0.02, mom_coeff=0.9)



learning_rule_1.initialise(model_1.params)
learning_rule_2.initialise(model_2.params)
learning_rule_3.initialise(model_3.params)



for inputs_batch, targets_batch in train_set:
    
    
    activations_1 = model_1.fprop(inputs_batch)
    grads_wrt_outputs_1 = error.grad(activations_1[-1], targets_batch)
    grads_wrt_params_1 = model_1.grads_wrt_params(
        activations_1, grads_wrt_outputs_1)
    learning_rule_1.update_params(grads_wrt_params_1)
    
    inputs_batch, targets_batch = train_set.next()
    activations_2 = model_2.fprop(inputs_batch)
    grads_wrt_outputs_2 = error.grad(activations_2[-1], targets_batch)
    grads_wrt_params_2 = model_2.grads_wrt_params(
        activations_2, grads_wrt_outputs_2)
    learning_rule_2.update_params(grads_wrt_params_2)
    
    inputs_batch, targets_batch = train_set.next()
    activations_3 = model_3.fprop(inputs_batch)
    grads_wrt_outputs_3 = error.grad(activations_3[-1], targets_batch)
    grads_wrt_params_3 = model_3.grads_wrt_params(
        activations_3, grads_wrt_outputs_3)
    learning_rule_3.update_params(grads_wrt_params_3)
    
    inputs_batch, targets_batch = train_set.next()
    activations_1 = model_1.fprop(inputs_batch)
    e1 = error(activations_1[-1], targets_batch)
    activations_2 = model_2.fprop(inputs_batch)
    e2 = error(activations_2[-1], targets_batch)
    activations_3 = model_3.fprop(inputs_batch)
    e3 = error(activations_3[-1], targets_batch)
    e = [e1, e2, e3]
    print e
    idx = e.index(min(e))

    if idx == 0:
        model_2.set_params(copy.copy(model_1.params))
        model_3.set_params(copy.copy(model_1.params))
    elif idx==1:
        model_1.set_params(copy.copy(model_2.params))
        model_3.set_params(copy.copy(model_2.params))
    elif idx==2:
        model_1.set_params(copy.copy(model_3.params))
        model_2.set_params(copy.copy(model_3.params))
# Out:
# [2.3575114457003643, 2.3469643820466239, 2.3585207334952689]
# 100 #
# 100 #
# 100 #
# 100 #
# 100 #
# 100 #
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-c3922c991656> in <module>()
#      20
#      21
# ---> 22     activations_1 = model_1.fprop(inputs_batch)
#      23     grads_wrt_outputs_1 = error.grad(activations_1[-1], targets_batch)
#      24     grads_wrt_params_1 = model_1.grads_wrt_params(
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/models.py in fprop(self, inputs, stochastic)
#     123                     activations[i], stochastic=stochastic))
#     124             else:
# --> 125                 activations.append(self.layers[i].fprop(activations[i]))
#     126         return activations
#     127
#
# /Users/Aaron-MAC/Development/Courses/MLP2/mlp/layers.pyc in fprop(self, inputs)
#     197             outputs: Array of layer outputs of shape (batch_size, output_dim).
#     198         """
# --> 199         return self.weights.dot(inputs.T).T + self.biases
#     200
#     201     def bprop(self, inputs, outputs, grads_wrt_outputs):
#
# ValueError: operands could not be broadcast together with shapes (100,) (784,)
