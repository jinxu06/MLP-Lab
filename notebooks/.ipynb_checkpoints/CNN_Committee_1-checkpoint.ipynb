# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
import cPickle as pickle
# %matplotlib inline
plt.style.use('ggplot')
# %load_ext autoreload
# %autoreload 2

logger = logging.getLogger()
logger.setLevel("INFO") 
logger.handlers = [logging.StreamHandler()] 
seed = 20161121
rng = np.random.RandomState(seed)

# %%
from mlp.models import MultipleLayerModel
from mlp.layers import AffineLayer, ConvolutionalLayer, MaxPoolingLayer, ReshapeLayer
from mlp.layers import SigmoidLayer, TanhLayer, ReluLayer, DropoutLayer
from mlp.data_providers import MNISTDataProvider, MNISTCNNAutoencoderDataProvider, MNISTCNNDataProvider
from mlp.data_providers import MNISTCNNDenoisingAutoencoderDataProvider
from mlp.data_providers import MNISTCNNResizeDataProvider
from mlp.errors import CNNSumOfSquaredDiffsError, CrossEntropySoftmaxError
from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule
from mlp.schedulers import ConstantLearningRateScheduler, ExponentialLearningRateScheduler
from mlp.penalties import L1Penalty, L2Penalty
from mlp.initialisers import GlorotUniformInit, ConstantInit, UniformInit
from mlp.optimisers import Optimiser
from mlp.settings import Setting
from mlp.experiments import Experiment

# %%
kernels_init = UniformInit(-0.01,0.01,rng=rng)
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

learning_rule = MomentumLearningRule(learning_rate=0.02, mom_coeff=0.9)
error = CrossEntropySoftmaxError()
ae_error = CNNSumOfSquaredDiffsError()

# %%
train_set = MNISTCNNResizeDataProvider(img_width=20, which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNResizeDataProvider(img_width=20, which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)

# %%
a,_ = train_set.next()
from mlp.visualisers import show_batch_of_images
show_batch_of_images(a[:,0,:,:])
# Out:
# (<matplotlib.figure.Figure at 0x10d2a4690>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10db40650>)

# %%
train_set = MNISTCNNResizeDataProvider(img_width=20, which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNResizeDataProvider(img_width=20, which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=12*12*4, output_dim=100, weights_initialiser=weights_init),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN Expert 20"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()

with open("expert_model_20.pkl", 'wb') as f:
    pickle.dump(model, f)
# Out:
# Epoch 0:
#   error(train)=2.56e+00, acc(train)=1.30e-01, error(valid)=2.56e+00, acc(valid)=1.28e-01, params_penalty=0.00e+00
# Epoch 1: 47.49s to complete
#   error(train)=1.66e-01, acc(train)=9.49e-01, error(valid)=1.63e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00

# %%
train_set = MNISTCNNResizeDataProvider(img_width=24, which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNResizeDataProvider(img_width=24, which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=12*12*4, output_dim=100, weights_initialiser=weights_init),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN Expert 24"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()

with open("expert_model_24.pkl", 'wb') as f:
    pickle.dump(model, f)
# Out:
# Epoch 0:
#   error(train)=2.66e+00, acc(train)=9.09e-02, error(valid)=2.67e+00, acc(valid)=8.98e-02, params_penalty=0.00e+00
# Epoch 1: 46.44s to complete
#   error(train)=1.65e-01, acc(train)=9.51e-01, error(valid)=1.57e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Epoch 2: 45.08s to complete
#   error(train)=1.27e-01, acc(train)=9.61e-01, error(valid)=1.38e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Epoch 3: 45.43s to complete
#   error(train)=8.84e-02, acc(train)=9.73e-01, error(valid)=1.02e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 4: 44.81s to complete
#   error(train)=9.23e-02, acc(train)=9.70e-01, error(valid)=1.13e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 5: 47.67s to complete
#   error(train)=6.52e-02, acc(train)=9.81e-01, error(valid)=8.61e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 6: 44.82s to complete
#   error(train)=9.46e-02, acc(train)=9.69e-01, error(valid)=1.12e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 7: 47.24s to complete
#   error(train)=8.46e-02, acc(train)=9.73e-01, error(valid)=1.18e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# Epoch 8: 47.01s to complete
#   error(train)=5.51e-02, acc(train)=9.84e-01, error(valid)=9.11e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 9: 45.46s to complete
#   error(train)=4.52e-02, acc(train)=9.86e-01, error(valid)=8.47e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 10: 51.96s to complete
#   error(train)=4.03e-02, acc(train)=9.89e-01, error(valid)=7.94e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 11: 46.27s to complete
#   error(train)=3.12e-02, acc(train)=9.92e-01, error(valid)=7.29e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 12: 46.22s to complete
#   error(train)=3.12e-02, acc(train)=9.91e-01, error(valid)=7.31e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 13: 45.15s to complete
#   error(train)=2.45e-02, acc(train)=9.94e-01, error(valid)=7.03e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 14: 45.65s to complete
#   error(train)=2.56e-02, acc(train)=9.93e-01, error(valid)=7.35e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 15: 46.07s to complete
#   error(train)=2.13e-02, acc(train)=9.95e-01, error(valid)=7.00e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 16: 45.87s to complete
#   error(train)=2.02e-02, acc(train)=9.95e-01, error(valid)=7.54e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 17: 45.73s to complete
#   error(train)=1.74e-02, acc(train)=9.96e-01, error(valid)=7.37e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 18: 44.88s to complete
#   error(train)=1.54e-02, acc(train)=9.97e-01, error(valid)=6.86e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 19: 44.36s to complete
#   error(train)=1.46e-02, acc(train)=9.97e-01, error(valid)=6.91e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 20: 47.94s to complete
#   error(train)=2.24e-02, acc(train)=9.93e-01, error(valid)=7.89e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 21: 45.54s to complete
#   error(train)=2.17e-02, acc(train)=9.94e-01, error(valid)=8.18e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 22: 46.94s to complete
#   error(train)=1.07e-02, acc(train)=9.98e-01, error(valid)=7.00e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 23: 47.33s to complete
#   error(train)=1.61e-02, acc(train)=9.96e-01, error(valid)=8.03e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 24: 53.71s to complete
#   error(train)=1.16e-02, acc(train)=9.98e-01, error(valid)=7.98e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 25: 47.28s to complete
#   error(train)=8.94e-03, acc(train)=9.99e-01, error(valid)=7.44e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 26: 49.66s to complete
#   error(train)=8.87e-03, acc(train)=9.98e-01, error(valid)=7.28e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 27: 46.38s to complete
#   error(train)=6.44e-03, acc(train)=1.00e+00, error(valid)=7.47e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 28: 45.87s to complete
#   error(train)=6.09e-03, acc(train)=1.00e+00, error(valid)=7.37e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 29: 44.39s to complete
#   error(train)=6.83e-03, acc(train)=9.99e-01, error(valid)=7.54e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 30: 45.36s to complete
#   error(train)=5.02e-03, acc(train)=1.00e+00, error(valid)=7.43e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00

# %%
train_set = MNISTCNNDataProvider(which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNDataProvider(which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=12*12*4, output_dim=100, weights_initialiser=weights_init),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN Expert"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()

with open("expert_model_28.pkl", 'wb') as f:
    pickle.dump(model, f)

# %%
acc = lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()
a = []
for inputs_batch, targets_batch in valid_set:
    predict = model.fprop(inputs_batch)[-1]
    a.append(acc(predict, targets_batch))
print np.mean(a)
# Out:
# 0.9508
