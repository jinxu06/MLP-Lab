# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
import cPickle as pickle
# %matplotlib inline
plt.style.use('ggplot')
# %load_ext autoreload
# %autoreload 2

logger = logging.getLogger()
logger.setLevel("INFO") 
logger.handlers = [logging.StreamHandler()] 
seed = 20161121
rng = np.random.RandomState(seed)

# %%
from mlp.models import MultipleLayerModel
from mlp.layers import AffineLayer, ConvolutionalLayer, MaxPoolingLayer, ReshapeLayer
from mlp.layers import SigmoidLayer, TanhLayer, ReluLayer, DropoutLayer
from mlp.data_providers import MNISTDataProvider, MNISTCNNAutoencoderDataProvider, MNISTCNNDataProvider
from mlp.data_providers import MNISTCNNDenoisingAutoencoderDataProvider
from mlp.errors import CNNSumOfSquaredDiffsError, CrossEntropySoftmaxError
from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule
from mlp.schedulers import ConstantLearningRateScheduler, ExponentialLearningRateScheduler
from mlp.penalties import L1Penalty, L2Penalty
from mlp.initialisers import GlorotUniformInit, ConstantInit, UniformInit
from mlp.optimisers import Optimiser
from mlp.settings import Setting
from mlp.experiments import Experiment

# %%
kernels_init = UniformInit(-0.01,0.01,rng=rng)
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

learning_rule = MomentumLearningRule(learning_rate=0.02, mom_coeff=0.9)
error = CrossEntropySoftmaxError()
ae_error = CNNSumOfSquaredDiffsError()

# %%
train_set = MNISTCNNDataProvider(which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNDataProvider(which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=12*12*4, output_dim=100, weights_initialiser=weights_init),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN Shallow"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()
# Out:
# Epoch 0:
#   error(train)=2.30e+00, acc(train)=1.06e-01, error(valid)=2.30e+00, acc(valid)=9.93e-02, params_penalty=0.00e+00
# Epoch 1: 50.93s to complete
#   error(train)=1.57e-01, acc(train)=9.56e-01, error(valid)=1.52e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# Epoch 2: 55.90s to complete
#   error(train)=9.38e-02, acc(train)=9.73e-01, error(valid)=9.87e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 3: 57.10s to complete
#   error(train)=6.93e-02, acc(train)=9.80e-01, error(valid)=8.03e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 4: 64.33s to complete
#   error(train)=5.89e-02, acc(train)=9.83e-01, error(valid)=7.62e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 5: 54.41s to complete
#   error(train)=4.32e-02, acc(train)=9.88e-01, error(valid)=6.27e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 6: 53.90s to complete
#   error(train)=3.92e-02, acc(train)=9.89e-01, error(valid)=6.38e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 7: 56.07s to complete
#   error(train)=3.08e-02, acc(train)=9.92e-01, error(valid)=5.52e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 8: 57.26s to complete
#   error(train)=3.08e-02, acc(train)=9.92e-01, error(valid)=5.59e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 9: 56.32s to complete
#   error(train)=2.44e-02, acc(train)=9.94e-01, error(valid)=5.32e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 10: 58.24s to complete
#   error(train)=2.09e-02, acc(train)=9.96e-01, error(valid)=5.26e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 11: 62.46s to complete
#   error(train)=1.83e-02, acc(train)=9.96e-01, error(valid)=5.05e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 12: 54.52s to complete
#   error(train)=1.67e-02, acc(train)=9.97e-01, error(valid)=4.98e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 13: 73.61s to complete
#   error(train)=1.41e-02, acc(train)=9.98e-01, error(valid)=5.05e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 14: 70.55s to complete
#   error(train)=1.29e-02, acc(train)=9.98e-01, error(valid)=5.05e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 15: 64.90s to complete
#   error(train)=1.16e-02, acc(train)=9.98e-01, error(valid)=4.93e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 16: 59.24s to complete
#   error(train)=1.08e-02, acc(train)=9.98e-01, error(valid)=4.88e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 17: 53.61s to complete
#   error(train)=9.64e-03, acc(train)=9.99e-01, error(valid)=4.95e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 18: 58.37s to complete
#   error(train)=9.40e-03, acc(train)=9.99e-01, error(valid)=4.99e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 19: 59.98s to complete
#   error(train)=7.75e-03, acc(train)=9.99e-01, error(valid)=4.77e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 20: 63.32s to complete
#   error(train)=8.41e-03, acc(train)=9.99e-01, error(valid)=4.96e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 21: 56.49s to complete
#   error(train)=6.02e-03, acc(train)=1.00e+00, error(valid)=4.81e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 22: 65.31s to complete
#   error(train)=5.59e-03, acc(train)=1.00e+00, error(valid)=4.82e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 23: 56.86s to complete
#   error(train)=5.18e-03, acc(train)=1.00e+00, error(valid)=5.02e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 24: 54.99s to complete
#   error(train)=4.62e-03, acc(train)=1.00e+00, error(valid)=4.96e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 25: 56.12s to complete
#   error(train)=4.85e-03, acc(train)=1.00e+00, error(valid)=4.79e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 26: 58.29s to complete
#   error(train)=4.12e-03, acc(train)=1.00e+00, error(valid)=4.90e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 27: 52.50s to complete
#   error(train)=3.93e-03, acc(train)=1.00e+00, error(valid)=4.91e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 28: 58.75s to complete
#   error(train)=3.53e-03, acc(train)=1.00e+00, error(valid)=4.99e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 29: 50.18s to complete
#   error(train)=3.46e-03, acc(train)=1.00e+00, error(valid)=4.90e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 30: 52.14s to complete
#   error(train)=3.15e-03, acc(train)=1.00e+00, error(valid)=4.90e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00

# %%
with open("cnn_shallow_model.pkl", 'wb') as f:
    pickle.dump(model, f)

# %%
train_set = MNISTCNNDataProvider(which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNDataProvider(which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    DropoutLayer(incl_prob=0.5),
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    DropoutLayer(incl_prob=0.1),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=12*12*4, output_dim=100, weights_initialiser=weights_init),
    TanhLayer(),
    DropoutLayer(incl_prob=0.5),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN Shallow dropout"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()
# Out:
# Epoch 0:
#   error(train)=2.30e+00, acc(train)=9.71e-02, error(valid)=2.30e+00, acc(valid)=1.00e-01, params_penalty=0.00e+00
# Epoch 1: 94.87s to complete
#   error(train)=1.04e+00, acc(train)=6.67e-01, error(valid)=9.98e-01, acc(valid)=6.88e-01, params_penalty=0.00e+00
# Epoch 2: 95.40s to complete
#   error(train)=9.17e-01, acc(train)=6.96e-01, error(valid)=8.82e-01, acc(valid)=7.14e-01, params_penalty=0.00e+00
# Epoch 3: 142.95s to complete
#   error(train)=7.97e-01, acc(train)=7.41e-01, error(valid)=7.14e-01, acc(valid)=7.75e-01, params_penalty=0.00e+00
# Epoch 4: 131.17s to complete
#   error(train)=7.83e-01, acc(train)=7.46e-01, error(valid)=7.17e-01, acc(valid)=7.71e-01, params_penalty=0.00e+00
# Epoch 5: 139.22s to complete
#   error(train)=7.56e-01, acc(train)=7.55e-01, error(valid)=6.90e-01, acc(valid)=7.73e-01, params_penalty=0.00e+00
# Epoch 6: 129.92s to complete
#   error(train)=7.43e-01, acc(train)=7.58e-01, error(valid)=6.69e-01, acc(valid)=7.85e-01, params_penalty=0.00e+00
# Epoch 7: 133.93s to complete
#   error(train)=7.30e-01, acc(train)=7.64e-01, error(valid)=6.81e-01, acc(valid)=7.77e-01, params_penalty=0.00e+00
# Epoch 8: 91.45s to complete
#   error(train)=7.16e-01, acc(train)=7.69e-01, error(valid)=6.49e-01, acc(valid)=8.02e-01, params_penalty=0.00e+00
# Epoch 9: 94.14s to complete
#   error(train)=6.95e-01, acc(train)=7.74e-01, error(valid)=6.41e-01, acc(valid)=7.92e-01, params_penalty=0.00e+00
# Epoch 10: 105.17s to complete
#   error(train)=7.03e-01, acc(train)=7.72e-01, error(valid)=6.29e-01, acc(valid)=7.97e-01, params_penalty=0.00e+00
# Epoch 11: 87.28s to complete
#   error(train)=6.75e-01, acc(train)=7.81e-01, error(valid)=6.19e-01, acc(valid)=8.02e-01, params_penalty=0.00e+00
# Epoch 12: 94.82s to complete
#   error(train)=6.84e-01, acc(train)=7.77e-01, error(valid)=6.13e-01, acc(valid)=8.05e-01, params_penalty=0.00e+00
# Epoch 13: 97.67s to complete
#   error(train)=6.70e-01, acc(train)=7.81e-01, error(valid)=6.32e-01, acc(valid)=7.91e-01, params_penalty=0.00e+00
# Epoch 14: 116.93s to complete
#   error(train)=6.59e-01, acc(train)=7.87e-01, error(valid)=6.02e-01, acc(valid)=8.10e-01, params_penalty=0.00e+00
# Epoch 15: 116.38s to complete
#   error(train)=6.58e-01, acc(train)=7.88e-01, error(valid)=6.08e-01, acc(valid)=8.02e-01, params_penalty=0.00e+00
# Epoch 16: 110.31s to complete
#   error(train)=6.61e-01, acc(train)=7.85e-01, error(valid)=6.07e-01, acc(valid)=8.04e-01, params_penalty=0.00e+00
# Epoch 17: 110.15s to complete
#   error(train)=6.42e-01, acc(train)=7.94e-01, error(valid)=5.90e-01, acc(valid)=8.11e-01, params_penalty=0.00e+00
# Epoch 18: 110.29s to complete
#   error(train)=6.43e-01, acc(train)=7.92e-01, error(valid)=6.15e-01, acc(valid)=8.04e-01, params_penalty=0.00e+00
# Epoch 19: 117.95s to complete
#   error(train)=6.53e-01, acc(train)=7.88e-01, error(valid)=5.89e-01, acc(valid)=8.12e-01, params_penalty=0.00e+00
# Epoch 20: 110.07s to complete
#   error(train)=6.32e-01, acc(train)=7.96e-01, error(valid)=5.71e-01, acc(valid)=8.18e-01, params_penalty=0.00e+00
# Epoch 21: 112.86s to complete
#   error(train)=6.28e-01, acc(train)=7.98e-01, error(valid)=5.72e-01, acc(valid)=8.12e-01, params_penalty=0.00e+00
# Epoch 22: 111.03s to complete
#   error(train)=6.35e-01, acc(train)=7.96e-01, error(valid)=5.86e-01, acc(valid)=8.09e-01, params_penalty=0.00e+00
# Epoch 23: 109.77s to complete
#   error(train)=6.36e-01, acc(train)=7.92e-01, error(valid)=5.61e-01, acc(valid)=8.21e-01, params_penalty=0.00e+00
# Epoch 24: 115.94s to complete
#   error(train)=6.30e-01, acc(train)=7.97e-01, error(valid)=5.79e-01, acc(valid)=8.13e-01, params_penalty=0.00e+00
# Epoch 25: 104.52s to complete
#   error(train)=6.34e-01, acc(train)=7.93e-01, error(valid)=5.92e-01, acc(valid)=8.06e-01, params_penalty=0.00e+00
# Epoch 26: 111.59s to complete
#   error(train)=6.18e-01, acc(train)=8.00e-01, error(valid)=5.68e-01, acc(valid)=8.15e-01, params_penalty=0.00e+00
# Epoch 27: 115.21s to complete
#   error(train)=6.15e-01, acc(train)=8.01e-01, error(valid)=5.83e-01, acc(valid)=8.14e-01, params_penalty=0.00e+00
# Epoch 28: 107.90s to complete
#   error(train)=6.15e-01, acc(train)=8.03e-01, error(valid)=5.70e-01, acc(valid)=8.18e-01, params_penalty=0.00e+00
# Epoch 29: 100.01s to complete
#   error(train)=6.12e-01, acc(train)=8.05e-01, error(valid)=5.53e-01, acc(valid)=8.26e-01, params_penalty=0.00e+00
# Epoch 30: 106.12s to complete
#   error(train)=6.08e-01, acc(train)=8.04e-01, error(valid)=5.44e-01, acc(valid)=8.26e-01, params_penalty=0.00e+00

# %%
train_set = MNISTCNNDataProvider(which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNDataProvider(which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    MaxPoolingLayer(),
    ConvolutionalLayer(num_input_channels=4, num_output_channels=12, 
                       input_dim_1=12, input_dim_2=12, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    TanhLayer(),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=4*4*12, output_dim=100, weights_initialiser=weights_init),
    TanhLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN deep tanh"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()
# Out:
# Epoch 0:
#   error(train)=2.30e+00, acc(train)=1.03e-01, error(valid)=2.30e+00, acc(valid)=1.05e-01, params_penalty=0.00e+00
# Epoch 1: 419.29s to complete
#   error(train)=1.25e-01, acc(train)=9.63e-01, error(valid)=1.21e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 2: 425.09s to complete
#   error(train)=7.67e-02, acc(train)=9.77e-01, error(valid)=8.32e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 3: 418.33s to complete
#   error(train)=6.14e-02, acc(train)=9.82e-01, error(valid)=7.00e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 4: 415.25s to complete
#   error(train)=4.63e-02, acc(train)=9.86e-01, error(valid)=6.08e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 5: 416.23s to complete
#   error(train)=4.08e-02, acc(train)=9.88e-01, error(valid)=5.65e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 6: 424.27s to complete
#   error(train)=3.57e-02, acc(train)=9.89e-01, error(valid)=5.28e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 7: 424.94s to complete
#   error(train)=3.01e-02, acc(train)=9.91e-01, error(valid)=5.23e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 8: 426.43s to complete
#   error(train)=2.81e-02, acc(train)=9.92e-01, error(valid)=4.99e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 9: 420.34s to complete
#   error(train)=2.93e-02, acc(train)=9.91e-01, error(valid)=5.40e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 10: 425.60s to complete
#   error(train)=2.18e-02, acc(train)=9.94e-01, error(valid)=4.90e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 11: 416.54s to complete
#   error(train)=2.08e-02, acc(train)=9.95e-01, error(valid)=4.81e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 12: 416.12s to complete
#   error(train)=1.89e-02, acc(train)=9.95e-01, error(valid)=5.09e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 13: 424.81s to complete
#   error(train)=1.69e-02, acc(train)=9.96e-01, error(valid)=5.03e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 14: 423.14s to complete
#   error(train)=1.59e-02, acc(train)=9.96e-01, error(valid)=4.87e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 15: 423.61s to complete
#   error(train)=1.39e-02, acc(train)=9.97e-01, error(valid)=4.93e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 16: 422.37s to complete
#   error(train)=1.34e-02, acc(train)=9.97e-01, error(valid)=4.98e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 17: 421.44s to complete
#   error(train)=1.12e-02, acc(train)=9.98e-01, error(valid)=4.93e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 18: 409.81s to complete
#   error(train)=1.01e-02, acc(train)=9.98e-01, error(valid)=4.87e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 19: 405.05s to complete
#   error(train)=9.53e-03, acc(train)=9.98e-01, error(valid)=4.79e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 20: 408.54s to complete
#   error(train)=1.09e-02, acc(train)=9.97e-01, error(valid)=5.20e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 21: 405.02s to complete
#   error(train)=7.89e-03, acc(train)=9.99e-01, error(valid)=4.89e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 22: 413.50s to complete
#   error(train)=7.98e-03, acc(train)=9.98e-01, error(valid)=5.31e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 23: 407.90s to complete
#   error(train)=6.39e-03, acc(train)=9.99e-01, error(valid)=4.93e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 24: 410.30s to complete
#   error(train)=6.39e-03, acc(train)=9.99e-01, error(valid)=5.02e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 25: 405.74s to complete
#   error(train)=5.93e-03, acc(train)=9.99e-01, error(valid)=5.06e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 26: 373.79s to complete
#   error(train)=5.51e-03, acc(train)=9.99e-01, error(valid)=5.23e-02, acc(valid)=9.86e-01, params_penalty=0.00e+00
# Epoch 27: 369.05s to complete
#   error(train)=5.20e-03, acc(train)=9.99e-01, error(valid)=5.13e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 28: 364.26s to complete
#   error(train)=4.66e-03, acc(train)=1.00e+00, error(valid)=5.05e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 29: 362.52s to complete
#   error(train)=4.09e-03, acc(train)=1.00e+00, error(valid)=5.15e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00
# Epoch 30: 362.70s to complete
#   error(train)=4.27e-03, acc(train)=1.00e+00, error(valid)=5.28e-02, acc(valid)=9.87e-01, params_penalty=0.00e+00

# %%
train_set = MNISTCNNDataProvider(which_set='train', batch_size=100, max_num_batches=-1, rng=rng)
valid_set = MNISTCNNDataProvider(which_set='valid', batch_size=100, max_num_batches=-1, rng=rng)


layers = [
    ConvolutionalLayer(num_input_channels=1, num_output_channels=4, 
                       input_dim_1=28, input_dim_2=28, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    ReluLayer(),
    MaxPoolingLayer(),
    ConvolutionalLayer(num_input_channels=4, num_output_channels=12, 
                       input_dim_1=12, input_dim_2=12, 
                       kernel_dim_1=5, kernel_dim_2=5, kernels_init=kernels_init),
    ReluLayer(),
    MaxPoolingLayer(),
    ReshapeLayer(),
    AffineLayer(input_dim=4*4*12, output_dim=100, weights_initialiser=weights_init),
    ReluLayer(),
    AffineLayer(input_dim=100, output_dim=10, weights_initialiser=weights_init),
]

model = MultipleLayerModel(layers)
setting = Setting(model, error, learning_rule, train_set, valid_set)

remark = "CNN deep relu"
settings = [setting]
experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
experiment.do_experiment()
# Out:
# Epoch 0:
#   error(train)=2.30e+00, acc(train)=1.00e-01, error(valid)=2.30e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9cb850909880> in <module>()
#      26 settings = [setting]
#      27 experiment = Experiment(settings=settings, num_epoch=30, stats_interval=1, remark=remark)
# ---> 28 experiment.do_experiment()
#
# /afs/inf.ed.ac.uk/user/s16/s1673820/MLP2/mlp/experiments.py in do_experiment(self)
#      47             optimiser = Optimiser(setting.model, setting.error, setting.learning_rule,
#      48                                   setting.train_set, setting.valid_set, self.data_monitors, setting.schedulers)
# ---> 49             stats, keys, run_time = optimiser.train(self.num_epoch, self.stats_interval)
#      50
#      51             with open(DIR+"/"+str(1)+"/activations.pkl", 'wb') as f:
#
# /afs/inf.ed.ac.uk/user/s16/s1673820/MLP2/mlp/optimisers.py in train(self, num_epochs, stats_interval)
#     147                 scheduler.update_learning_rule(self.learning_rule, epoch - 1)
#     148             start_time = time.time()
# --> 149             self.do_training_epoch()
#     150             epoch_time = time.time() - start_time
#     151             if epoch % stats_interval == 0:
#
# /afs/inf.ed.ac.uk/user/s16/s1673820/MLP2/mlp/optimisers.py in do_training_epoch(self)
#      66             grads_wrt_outputs = self.error.grad(activations[-1], targets_batch)
#      67             grads_wrt_params = self.model.grads_wrt_params(
# ---> 68                 activations, grads_wrt_outputs)
#      69             self.learning_rule.update_params(grads_wrt_params)
#      70
#
# /afs/inf.ed.ac.uk/user/s16/s1673820/MLP2/mlp/models.pyc in grads_wrt_params(self, activations, grads_wrt_outputs)
#     143             if i != len(self.layers) - 1:
#     144                 grads_wrt_outputs = layer.bprop(
# --> 145                     inputs, outputs, grads_wrt_outputs)
#     146         return grads_wrt_params[::-1]
#     147
#
# /afs/inf.ed.ac.uk/user/s16/s1673820/MLP2/mlp/layers.py in bprop(self, inputs, outputs, grads_wrt_outputs)
#     747             for j in range(self.num_output_channels):
#     748                 for k in range(self.num_input_channels):
# --> 749                     grads_wrt_inputs[i,k,:,:] += convolve2d(grads_wrt_outputs[i,j,:,:], kernels_rot[j,k,:,:], mode=self.grad_conv_mode)
#     750
#     751         grads_wrt_inputs = grads_wrt_inputs
#
# /afs/inf.ed.ac.uk/user/s16/s1673820/miniconda2/envs/mlp/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in convolve2d(in1, in2, mode, boundary, fillvalue)
#     711         warnings.simplefilter('ignore', np.ComplexWarning)
#     712         # FIXME: some cast generates a warning here
# --> 713         out = sigtools._convolve2d(in1, in2, 1, val, bval, fillvalue)
#     714
#     715     return out
#
# KeyboardInterrupt:
